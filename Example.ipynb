# %%
import datetime
import time

from Scweet.scweet import scrape
from Scweet.user import get_user_information, get_users_following, get_users_followers

# %% [markdown]
# # Scrape tweets of a specific account or words or hashtag

# %%
from dateutil import tz

# scrape top tweets with the words 'covid','covid19' in proximity and without replies.
# the process is slower as the interval is smaller (choose an interval that can divide the period of time betwee, start and max date)
until = datetime.datetime(2022, 8, 26, 13)
since = until - datetime.timedelta(minutes=1)

data = scrape(words=['bitcoin'], since=since, until=until, from_account=None,
              interval=datetime.timedelta(minutes=1),
              remote="http://35.192.100.243:4444",
              headless=False, filter_replies=False, proximity=False, proxy='http://lum-customer-c_759409a2-zone-datacenter-country-us:a352isr1i54w@zproxy.lum-superproxy.io:22225')
data
# Out:
# using proxy :  http://lum-customer-c_759409a2-zone-datacenter-country-us:a352isr1i54w@zproxy.lum-superproxy.io:22225
# looking for tweets between 2022-08-26 12:59:00 and 2022-08-26 13:00:00 ...
#  path : https://twitter.com/search?q=(bitcoin)%20until%3A1661518800%20since%3A1661518740%20&src=typed_query
# scroll  1
# scroll  2
# scroll  3
# scroll  4
# scroll  5
# scroll  6
# {'tweets': {'1563149144096915456': {'created_at': datetime.datetime(2022, 8, 26, 12, 59, 32),
#    'id': 1563149144096915456,
#    'id_str': '1563149144096915456',
#    'full_text': 'Norvell, Florida State look to turn back the clock https://t.co/jDqh2djmyF  ▶️ https://t.co/NKkDBWafkV #Bitcoin #Sportsbook',
#    'truncated': False,
#    'display_text_range': [0, 123],
#    'entities': {'hashtags': [{'text': 'Bitcoin', 'indices': [103, 111]},
#      {'text': 'Sportsbook', 'indices': [112, 123]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/jDqh2djmyF',
#       'expanded_url': 'http://dlvr.it/SXHBKD',
#       'display_url': 'dlvr.it/SXHBKD',
#       'indices': [51, 74]},
#      {'url': 'https://t.co/NKkDBWafkV',
#       'expanded_url': 'http://btf.st/odds',
#       'display_url': 'btf.st/odds',
#       'indices': [79, 102]}]},
#    'source': '<a href="https://dlvrit.com/" rel="nofollow">dlvr.it</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user_id': 2173508552,
#    'user_id_str': '2173508552',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'reply_count': 1,
#    'quote_count': 0,
#    'conversation_id': 1563149144096915456,
#    'conversation_id_str': '1563149144096915456',
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'possibly_sensitive_editable': True,
#    'card': {'name': 'summary_large_image',
#     'url': 'https://t.co/jDqh2djmyF',
#     'card_type_url': 'http://card-type-url-is-deprecated.invalid',
#     'binding_values': {'vanity_url': {'type': 'STRING',
#       'string_value': 'espn.com',
#       'scribe_key': 'vanity_url'},
#      'app_is_free': {'type': 'STRING', 'string_value': 'true'},
#      'app_price_currency': {'type': 'STRING', 'string_value': 'USD'},
#      'app_price_amount': {'type': 'STRING', 'string_value': '0.0'},
#      'domain': {'type': 'STRING', 'string_value': 'www.espn.com'},
#      'app_num_ratings': {'type': 'STRING', 'string_value': '1,898,948'},
#      'app_star_rating': {'type': 'STRING', 'string_value': '4.62039'},
#      'app_name': {'type': 'STRING',
#       'string_value': 'ESPN: Live Sports & Scores'},
#      'site': {'type': 'USER',
#       'user_value': {'id_str': '2557521', 'path': []},
#       'scribe_key': 'publisher_id'},
#      'title': {'type': 'STRING',
#       'string_value': "In college football's new world, Florida State looks to turn back the clock"},
#      'description': {'type': 'STRING',
#       'string_value': 'Amid growing fan negativity and a changing collegiate landscape, coach Mike Norvell needs to get the Seminoles pointed in the right direction after four straight losing seasons.'},
#      'thumbnail_image_small': {'type': 'IMAGE',
#       'image_value': {'url': 'https://pbs.twimg.com/card_img/1563146382034497538/N_b2ETcx?format=jpg&name=144x144',
#        'width': 144,
#        'height': 81,
#        'alt': None}},
#      'thumbnail_image': {'type': 'IMAGE',
#       'image_value': {'url': 'https://pbs.twimg.com/card_img/1563146382034497538/N_b2ETcx?format=jpg&name=280x150',
#        'width': 267,
#        'height': 150,
#        'alt': None}},
#      'thumbnail_image_large': {'type': 'IMAGE',
#       'image_value': {'url': 'https://pbs.twimg.com/card_img/1563146382034497538/N_b2ETcx?format=jpg&name=800x320_1',
#        'width': 569,
#        'height': 320,
#        'alt': None}},
#      'thumbnail_image_x_large': {'type': 'IMAGE',
#       'image_value': {'url': 'https://pbs.twimg.com/card_img/1563146382034497538/N_b2ETcx?format=png&name=2048x2048_2_exp',
#        'width': 1296,
#        'height': 729,
#        'alt': None}},
#      'thumbnail_image_color': {'type': 'IMAGE_COLOR',
#       'image_color_value': {'palette': [{'percentage': 43.62,
#          'rgb': {'red': 214, 'green': 181, 'blue': 183}},
#         {'percentage': 16.06, 'rgb': {'red': 185, 'green': 32, 'blue': 47}},
#         {'percentage': 6.62, 'rgb': {'red': 203, 'green': 146, 'blue': 119}},
#         {'percentage': 5.36, 'rgb': {'red': 102, 'green': 29, 'blue': 24}},
#         {'percentage': 5.16, 'rgb': {'red': 48, 'green': 37, 'blue': 36}}]}},
#      'thumbnail_image_original': {'type': 'IMAGE',
#       'image_value': {'url': 'https://pbs.twimg.com/card_img/1563146382034497538/N_b2ETcx?format=jpg&name=orig',
#        'width': 1296,
#        'height': 729,
#        'alt': None}},
#      'summary_photo_image_small': {'type': 'IMAGE',
#       'image_value': {'url': 'https://pbs.twimg.com/card_img/1563146382034497538/N_b2ETcx?format=jpg&name=386x202',
#        'width': 386,
#        'height': 202,
#        'alt': None}},
#      'summary_photo_image': {'type': 'IMAGE',
#       'image_value': {'url': 'https://pbs.twimg.com/card_img/1563146382034497538/N_b2ETcx?format=jpg&name=600x314',
#        'width': 600,
#        'height': 314,
#        'alt': None}},
#      'summary_photo_image_large': {'type': 'IMAGE',
#       'image_value': {'url': 'https://pbs.twimg.com/card_img/1563146382034497538/N_b2ETcx?format=jpg&name=800x419',
#        'width': 800,
#        'height': 419,
#        'alt': None}},
#      'summary_photo_image_x_large': {'type': 'IMAGE',
#       'image_value': {'url': 'https://pbs.twimg.com/card_img/1563146382034497538/N_b2ETcx?format=png&name=2048x2048_2_exp',
#        'width': 1296,
#        'height': 729,
#        'alt': None}},
#      'summary_photo_image_color': {'type': 'IMAGE_COLOR',
#       'image_color_value': {'palette': [{'percentage': 43.62,
#          'rgb': {'red': 214, 'green': 181, 'blue': 183}},
#         {'percentage': 16.06, 'rgb': {'red': 185, 'green': 32, 'blue': 47}},
#         {'percentage': 6.62, 'rgb': {'red': 203, 'green': 146, 'blue': 119}},
#         {'percentage': 5.36, 'rgb': {'red': 102, 'green': 29, 'blue': 24}},
#         {'percentage': 5.16, 'rgb': {'red': 48, 'green': 37, 'blue': 36}}]}},
#      'summary_photo_image_original': {'type': 'IMAGE',
#       'image_value': {'url': 'https://pbs.twimg.com/card_img/1563146382034497538/N_b2ETcx?format=jpg&name=orig',
#        'width': 1296,
#        'height': 729,
#        'alt': None}},
#      'photo_image_full_size_small': {'type': 'IMAGE',
#       'image_value': {'url': 'https://pbs.twimg.com/card_img/1563146382034497538/N_b2ETcx?format=jpg&name=386x202',
#        'width': 386,
#        'height': 202,
#        'alt': None}},
#      'photo_image_full_size': {'type': 'IMAGE',
#       'image_value': {'url': 'https://pbs.twimg.com/card_img/1563146382034497538/N_b2ETcx?format=jpg&name=600x314',
#        'width': 600,
#        'height': 314,
#        'alt': None}},
#      'photo_image_full_size_large': {'type': 'IMAGE',
#       'image_value': {'url': 'https://pbs.twimg.com/card_img/1563146382034497538/N_b2ETcx?format=jpg&name=800x419',
#        'width': 800,
#        'height': 419,
#        'alt': None}},
#      'photo_image_full_size_x_large': {'type': 'IMAGE',
#       'image_value': {'url': 'https://pbs.twimg.com/card_img/1563146382034497538/N_b2ETcx?format=png&name=2048x2048_2_exp',
#        'width': 1296,
#        'height': 729,
#        'alt': None}},
#      'photo_image_full_size_color': {'type': 'IMAGE_COLOR',
#       'image_color_value': {'palette': [{'percentage': 43.62,
#          'rgb': {'red': 214, 'green': 181, 'blue': 183}},
#         {'percentage': 16.06, 'rgb': {'red': 185, 'green': 32, 'blue': 47}},
#         {'percentage': 6.62, 'rgb': {'red': 203, 'green': 146, 'blue': 119}},
#         {'percentage': 5.36, 'rgb': {'red': 102, 'green': 29, 'blue': 24}},
#         {'percentage': 5.16, 'rgb': {'red': 48, 'green': 37, 'blue': 36}}]}},
#      'photo_image_full_size_original': {'type': 'IMAGE',
#       'image_value': {'url': 'https://pbs.twimg.com/card_img/1563146382034497538/N_b2ETcx?format=jpg&name=orig',
#        'width': 1296,
#        'height': 729,
#        'alt': None}},
#      'card_url': {'type': 'STRING',
#       'string_value': 'https://t.co/jDqh2djmyF',
#       'scribe_key': 'card_url'}},
#     'users': {'2557521': {'id': 2557521,
#       'id_str': '2557521',
#       'name': 'ESPN',
#       'screen_name': 'espn',
#       'location': '',
#       'description': 'Serving sports fans. Anytime. Anywhere.',
#       'url': 'https://t.co/MJhKyVN8QD',
#       'entities': {'url': {'urls': [{'url': 'https://t.co/MJhKyVN8QD',
#           'expanded_url': 'https://www.espn.com/',
#           'display_url': 'espn.com',
#           'indices': [0, 23]}]},
#        'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 41494536,
#       'fast_followers_count': 0,
#       'normal_followers_count': 41494536,
#       'friends_count': 422,
#       'listed_count': 60290,
#       'created_at': 'Tue Mar 27 20:46:16 +0000 2007',
#       'favourites_count': 2555,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': True,
#       'verified': True,
#       'statuses_count': 132130,
#       'media_count': 45171,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': True,
#       'profile_background_color': 'C8C8C8',
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1170690523201527808/FriNRiir_normal.png',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1170690523201527808/FriNRiir_normal.png',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2557521/1656522193',
#       'profile_image_extensions_sensitive_media_warning': None,
#       'profile_image_extensions_media_availability': None,
#       'profile_image_extensions_alt_text': None,
#       'profile_image_extensions_media_color': {'palette': [{'rgb': {'red': 255,
#           'green': 255,
#           'blue': 255},
#          'percentage': 78.77},
#         {'rgb': {'red': 204, 'green': 0, 'blue': 0}, 'percentage': 19.91},
#         {'rgb': {'red': 232, 'green': 143, 'blue': 143}, 'percentage': 0.73},
#         {'rgb': {'red': 220, 'green': 82, 'blue': 82}, 'percentage': 0.6}]},
#       'profile_image_extensions': {'mediaStats': {'r': {'missing': None},
#         'ttl': -1}},
#       'profile_banner_extensions_sensitive_media_warning': None,
#       'profile_banner_extensions_media_availability': None,
#       'profile_banner_extensions_alt_text': None,
#       'profile_banner_extensions_media_color': {'palette': [{'rgb': {'red': 228,
#           'green': 22,
#           'blue': 8},
#          'percentage': 94.06},
#         {'rgb': {'red': 254, 'green': 247, 'blue': 246}, 'percentage': 2.87},
#         {'rgb': {'red': 237, 'green': 102, 'blue': 92}, 'percentage': 1.84},
#         {'rgb': {'red': 246, 'green': 171, 'blue': 166}, 'percentage': 1.04},
#         {'rgb': {'red': 234, 'green': 78, 'blue': 66}, 'percentage': 0.11}]},
#       'profile_banner_extensions': {'mediaStats': {'r': {'missing': None},
#         'ttl': -1}},
#       'profile_link_color': 'CC0000',
#       'profile_sidebar_border_color': 'FFFFFF',
#       'profile_sidebar_fill_color': 'EFEFEF',
#       'profile_text_color': '333333',
#       'profile_use_background_image': True,
#       'has_extended_profile': False,
#       'default_profile': False,
#       'default_profile_image': False,
#       'pinned_tweet_ids': [],
#       'pinned_tweet_ids_str': [],
#       'has_custom_timelines': True,
#       'can_dm': None,
#       'following': None,
#       'follow_request_sent': None,
#       'notifications': None,
#       'muting': None,
#       'blocking': None,
#       'blocked_by': None,
#       'want_retweets': None,
#       'advertiser_account_type': 'promotable_user',
#       'advertiser_account_service_levels': ['dso',
#        'dso',
#        'dso',
#        'dso',
#        'mms',
#        'analytics',
#        'media_studio'],
#       'profile_interstitial_type': '',
#       'business_profile_state': 'none',
#       'translator_type': 'regular',
#       'withheld_in_countries': [],
#       'followed_by': None,
#       'ext_has_nft_avatar': False,
#       'ext': {'highlightedLabel': {'r': {'ok': {}}, 'ttl': -1},
#        'hasNftAvatar': {'r': {'ok': False}, 'ttl': -1},
#        'superFollowMetadata': {'r': {'ok': {'superFollowEligible': False,
#           'superFollowing': False,
#           'superFollowedBy': False,
#           'exclusiveTweetFollowing': False,
#           'privateSuperFollowing': False}},
#         'ttl': -1}},
#       'require_some_consent': False}},
#     'card_platform': {'platform': {'device': {'name': 'Swift',
#        'version': '12'},
#       'audience': {'name': 'production', 'bucket': None}}}},
#    'lang': 'en',
#    'supplemental_language': None,
#    'ext_edit_control': {'initial': {'edit_tweet_ids': ['1563149144096915456'],
#      'editable_until_msecs': '1661520572000',
#      'edits_remaining': '5',
#      'is_edit_eligible': True}},
#    'ext': {'unmentionInfo': {'r': {'ok': {}}, 'ttl': -1},
#     'superFollowMetadata': {'r': {'ok': {}}, 'ttl': -1},
#     'editControl': {'r': {'ok': {'initial': {'editTweetIds': ['1563149144096915456'],
#         'editableUntilMsecs': '1661520572000',
#         'editsRemaining': '5',
#         'isEditEligible': True}}},
#      'ttl': -1}}},
#   '1563149008620642304': {'created_at': datetime.datetime(2022, 8, 26, 12, 59),
#    'id': 1563149008620642304,
#    'id_str': '1563149008620642304',
#    'full_text': "We're hiring 🧑\u200d💻\n\nLet's build the Bitcoin economy👇\n\nhttps://t.co/Ebktca8OBw",
#    'truncated': False,
#    'display_text_range': [0, 75],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/Ebktca8OBw',
#       'expanded_url': 'https://cryptocurrencyjobs.co/engineering/zest-protocol-full-stack-developer-bitcoin-defi/',
#       'display_url': 'cryptocurrencyjobs.co/engineering/ze…',
#       'indices': [52, 75]}]},
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user_id': 1493952977006219266,
#    'user_id_str': '1493952977006219266',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 7,
#    'reply_count': 0,
#    'quote_count': 2,
#    'conversation_id': 1563149008620642304,
#    'conversation_id_str': '1563149008620642304',
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'possibly_sensitive_editable': True,
#    'card': {'name': 'summary',
#     'url': 'https://t.co/Ebktca8OBw',
#     'card_type_url': 'http://card-type-url-is-deprecated.invalid',
#     'binding_values': {'vanity_url': {'type': 'STRING',
#       'string_value': 'cryptocurrencyjobs.co',
#       'scribe_key': 'vanity_url'},
#      'domain': {'type': 'STRING', 'string_value': 'cryptocurrencyjobs.co'},
#      'site': {'type': 'USER',
#       'user_value': {'id_str': '919314949909958658', 'path': []},
#       'scribe_key': 'publisher_id'},
#      'title': {'type': 'STRING',
#       'string_value': 'Full Stack Developer (Bitcoin DeFi) at Zest Protocol'},
#      'description': {'type': 'STRING',
#       'string_value': 'Zest Protocol is looking to hire a Full Stack Developer (Bitcoin DeFi) to join their team. This is a full-time position that is 100% remote with no geographical restrictions. Work remotely from...'},
#      'thumbnail_image_small': {'type': 'IMAGE',
#       'image_value': {'url': 'https://pbs.twimg.com/card_img/1563121094567120896/jtom8xkl?format=jpg&name=100x100_2',
#        'width': 100,
#        'height': 100,
#        'alt': None}},
#      'thumbnail_image': {'type': 'IMAGE',
#       'image_value': {'url': 'https://pbs.twimg.com/card_img/1563121094567120896/jtom8xkl?format=jpg&name=144x144_2',
#        'width': 144,
#        'height': 144,
#        'alt': None}},
#      'thumbnail_image_large': {'type': 'IMAGE',
#       'image_value': {'url': 'https://pbs.twimg.com/card_img/1563121094567120896/jtom8xkl?format=jpg&name=420x420_2',
#        'width': 400,
#        'height': 400,
#        'alt': None}},
#      'thumbnail_image_x_large': {'type': 'IMAGE',
#       'image_value': {'url': 'https://pbs.twimg.com/card_img/1563121094567120896/jtom8xkl?format=png&name=2048x2048_2_exp',
#        'width': 400,
#        'height': 400,
#        'alt': None}},
#      'thumbnail_image_color': {'type': 'IMAGE_COLOR',
#       'image_color_value': {'palette': [{'percentage': 67.35,
#          'rgb': {'red': 255, 'green': 251, 'blue': 195}},
#         {'percentage': 24.72, 'rgb': {'red': 254, 'green': 104, 'blue': 2}},
#         {'percentage': 5.65, 'rgb': {'red': 237, 'green': 149, 'blue': 64}},
#         {'percentage': 1.85, 'rgb': {'red': 244, 'green': 190, 'blue': 116}},
#         {'percentage': 0.16,
#          'rgb': {'red': 246, 'green': 204, 'blue': 125}}]}},
#      'thumbnail_image_original': {'type': 'IMAGE',
#       'image_value': {'url': 'https://pbs.twimg.com/card_img/1563121094567120896/jtom8xkl?format=jpg&name=orig',
#        'width': 400,
#        'height': 400,
#        'alt': None}},
#      'card_url': {'type': 'STRING',
#       'string_value': 'https://t.co/Ebktca8OBw',
#       'scribe_key': 'card_url'}},
#     'users': {'919314949909958658': {'id': 919314949909958658,
#       'id_str': '919314949909958658',
#       'name': 'Cryptocurrency Jobs',
#       'screen_name': 'jobsincrypto',
#       'location': '',
#       'description': 'The leading job board for blockchain & cryptocurrency jobs. Building the decentralized future takes people from devs to writers working together. Made by @3reps',
#       'url': 'https://t.co/K2RRqtCcBP',
#       'entities': {'url': {'urls': [{'url': 'https://t.co/K2RRqtCcBP',
#           'expanded_url': 'https://cryptocurrencyjobs.co/',
#           'display_url': 'cryptocurrencyjobs.co',
#           'indices': [0, 23]}]},
#        'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 24964,
#       'fast_followers_count': 0,
#       'normal_followers_count': 24964,
#       'friends_count': 591,
#       'listed_count': 409,
#       'created_at': 'Sat Oct 14 21:32:18 +0000 2017',
#       'favourites_count': 12507,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': False,
#       'verified': False,
#       'statuses_count': 37964,
#       'media_count': 50,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': 'F5F8FA',
#       'profile_background_image_url': None,
#       'profile_background_image_url_https': None,
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1459625020351733770/bjyZ9Xp1_normal.png',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1459625020351733770/bjyZ9Xp1_normal.png',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/919314949909958658/1636836700',
#       'profile_image_extensions_sensitive_media_warning': None,
#       'profile_image_extensions_media_availability': None,
#       'profile_image_extensions_alt_text': None,
#       'profile_image_extensions_media_color': {'palette': [{'rgb': {'red': 1,
#           'green': 25,
#           'blue': 45},
#          'percentage': 80.05},
#         {'rgb': {'red': 255, 'green': 255, 'blue': 255}, 'percentage': 14.05},
#         {'rgb': {'red': 17, 'green': 227, 'blue': 17}, 'percentage': 5.32},
#         {'rgb': {'red': 121, 'green': 237, 'blue': 121}, 'percentage': 0.13},
#         {'rgb': {'red': 187, 'green': 252, 'blue': 188}, 'percentage': 0.12}]},
#       'profile_image_extensions': {'mediaStats': {'r': {'missing': None},
#         'ttl': -1}},
#       'profile_banner_extensions_sensitive_media_warning': None,
#       'profile_banner_extensions_media_availability': None,
#       'profile_banner_extensions_alt_text': None,
#       'profile_banner_extensions_media_color': {'palette': [{'rgb': {'red': 5,
#           'green': 27,
#           'blue': 45},
#          'percentage': 96.86},
#         {'rgb': {'red': 151, 'green': 160, 'blue': 168}, 'percentage': 2.73},
#         {'rgb': {'red': 97, 'green': 110, 'blue': 121}, 'percentage': 0.87}]},
#       'profile_banner_extensions': {'mediaStats': {'r': {'missing': None},
#         'ttl': -1}},
#       'profile_link_color': '1DA1F2',
#       'profile_sidebar_border_color': 'C0DEED',
#       'profile_sidebar_fill_color': 'DDEEF6',
#       'profile_text_color': '333333',
#       'profile_use_background_image': True,
#       'has_extended_profile': False,
#       'default_profile': True,
#       'default_profile_image': False,
#       'pinned_tweet_ids': [1357448536795807755],
#       'pinned_tweet_ids_str': ['1357448536795807755'],
#       'has_custom_timelines': False,
#       'can_dm': None,
#       'following': None,
#       'follow_request_sent': None,
#       'notifications': None,
#       'muting': None,
#       'blocking': None,
#       'blocked_by': None,
#       'want_retweets': None,
#       'advertiser_account_type': 'promotable_user',
#       'advertiser_account_service_levels': ['analytics'],
#       'profile_interstitial_type': '',
#       'business_profile_state': 'none',
#       'translator_type': 'none',
#       'withheld_in_countries': [],
#       'followed_by': None,
#       'ext_has_nft_avatar': False,
#       'ext': {'hasNftAvatar': {'r': {'ok': False}, 'ttl': -1},
#        'superFollowMetadata': {'r': {'ok': {'superFollowEligible': False,
#           'superFollowing': False,
#           'superFollowedBy': False,
#           'exclusiveTweetFollowing': False,
#           'privateSuperFollowing': False}},
#         'ttl': -1},
#        'highlightedLabel': {'r': {'ok': {}}, 'ttl': -1}},
#       'require_some_consent': False}},
#     'card_platform': {'platform': {'device': {'name': 'Swift',
#        'version': '12'},
#       'audience': {'name': 'production', 'bucket': None}}}},
#    'lang': 'en',
#    'supplemental_language': None,
#    'ext_edit_control': {'initial': {'edit_tweet_ids': ['1563149008620642304'],
#      'editable_until_msecs': '1661520540000',
#      'edits_remaining': '5',
#      'is_edit_eligible': True}},
#    'ext': {'superFollowMetadata': {'r': {'ok': {}}, 'ttl': -1},
#     'unmentionInfo': {'r': {'ok': {}}, 'ttl': -1},
#     'editControl': {'r': {'ok': {'initial': {'editTweetIds': ['1563149008620642304'],
#         'editableUntilMsecs': '1661520540000',
#         'editsRemaining': '5',
#         'isEditEligible': True}}},
#      'ttl': -1}}},
#   '1563149203739594752': {'created_at': datetime.datetime(2022, 8, 26, 12, 59, 46),
#    'id': 1563149203739594752,
#    'id_str': '1563149203739594752',
#    'full_text': 'And also to #bitcoin tips by @elonmusk 😂. Do you agree @ParikPatelCFA ?',
#    'truncated': False,
#    'display_text_range': [0, 71],
#    'entities': {'hashtags': [{'text': 'bitcoin', 'indices': [12, 20]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'elonmusk',
#       'name': 'Elon Musk',
#       'id': 44196397,
#       'id_str': '44196397',
#       'indices': [29, 38]},
#      {'screen_name': 'ParikPatelCFA',
#       'name': 'Dr. Parik Patel, BA, CFA, ACCA Esq. (drpatel.eth)',
#       'id': 1295526279194828800,
#       'id_str': '1295526279194828800',
#       'indices': [55, 69]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user_id': 14893301,
#    'user_id_str': '14893301',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1562880200752259072,
#    'quoted_status_id_str': '1562880200752259072',
#    'quoted_status_permalink': {'url': 'https://t.co/QvxpGEXv4D',
#     'expanded': 'https://twitter.com/rohitmat/status/1562880200752259072',
#     'display': 'twitter.com/rohitmat/statu…'},
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'reply_count': 0,
#    'quote_count': 0,
#    'conversation_id': 1563149203739594752,
#    'conversation_id_str': '1563149203739594752',
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en',
#    'supplemental_language': None,
#    'ext_edit_control': {'initial': {'edit_tweet_ids': ['1563149203739594752'],
#      'editable_until_msecs': '1661520586000',
#      'edits_remaining': '5',
#      'is_edit_eligible': True}},
#    'ext': {'superFollowMetadata': {'r': {'ok': {}}, 'ttl': -1},
#     'editControl': {'r': {'ok': {'initial': {'editTweetIds': ['1563149203739594752'],
#         'editableUntilMsecs': '1661520586000',
#         'editsRemaining': '5',
#         'isEditEligible': True}}},
#      'ttl': -1},
#     'unmentionInfo': {'r': {'ok': {}}, 'ttl': -1}}},
#   '1563149214334328833': {'created_at': datetime.datetime(2022, 8, 26, 12, 59, 49),
#    'id': 1563149214334328833,
#    'id_str': '1563149214334328833',
#    'full_text': '#BinanceCoin price update: $BNB\n\n#BNB $298.7 USD\n\n#Bitcoin 0.0138 BTC\n\n#Ethereum 0.17776 ETH\n\n#altcoin #crypto #cryptocurrency\n\nFollow for recent BNB price updates',
#    'truncated': False,
#    'display_text_range': [0, 163],
#    'entities': {'hashtags': [{'text': 'BinanceCoin', 'indices': [0, 12]},
#      {'text': 'BNB', 'indices': [33, 37]},
#      {'text': 'Bitcoin', 'indices': [50, 58]},
#      {'text': 'Ethereum', 'indices': [71, 80]},
#      {'text': 'altcoin', 'indices': [94, 102]},
#      {'text': 'crypto', 'indices': [103, 110]},
#      {'text': 'cryptocurrency', 'indices': [111, 126]}],
#     'symbols': [{'text': 'BNB', 'indices': [27, 31]}],
#     'user_mentions': [],
#     'urls': []},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user_id': 1546364668503298048,
#    'user_id_str': '1546364668503298048',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'reply_count': 0,
#    'quote_count': 0,
#    'conversation_id': 1563149214334328833,
#    'conversation_id_str': '1563149214334328833',
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en',
#    'supplemental_language': None,
#    'ext_edit_control': {'initial': {'edit_tweet_ids': ['1563149214334328833'],
#      'editable_until_msecs': '1661520589000',
#      'edits_remaining': '5',
#      'is_edit_eligible': True}},
#    'ext': {'superFollowMetadata': {'r': {'ok': {}}, 'ttl': -1},
#     'editControl': {'r': {'ok': {'initial': {'editTweetIds': ['1563149214334328833'],
#         'editableUntilMsecs': '1661520589000',
#         'editsRemaining': '5',
#         'isEditEligible': True}}},
#      'ttl': -1},
#     'unmentionInfo': {'r': {'ok': {}}, 'ttl': -1}}},
#   '1563149113012928512': {'created_at': datetime.datetime(2022, 8, 26, 12, 59, 25),
#    'id': 1563149113012928512,
#    'id_str': '1563149113012928512',
#    'full_text': '@Bitcoin__Banks I think a great short is setting up',
#    'truncated': False,
#    'display_text_range': [16, 51],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Bitcoin__Banks',
#       'name': '₿ANKS',
#       'id': 1335488314607067139,
#       'id_str': '1335488314607067139',
#       'indices': [0, 15]}],
#     'urls': []},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1563144855303651328,
#    'in_reply_to_status_id_str': '1563144855303651328',
#    'in_reply_to_user_id': 1335488314607067139,
#    'in_reply_to_user_id_str': '1335488314607067139',
#    'in_reply_to_screen_name': 'Bitcoin__Banks',
#    'user_id': 1360158486852743169,
#    'user_id_str': '1360158486852743169',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'reply_count': 1,
#    'quote_count': 0,
#    'conversation_id': 1563144855303651328,
#    'conversation_id_str': '1563144855303651328',
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en',
#    'supplemental_language': None,
#    'ext_edit_control': {'initial': {'edit_tweet_ids': ['1563149113012928512'],
#      'editable_until_msecs': '1661520565000',
#      'edits_remaining': '5',
#      'is_edit_eligible': False}},
#    'ext': {'unmentionInfo': {'r': {'ok': {}}, 'ttl': -1},
#     'editControl': {'r': {'ok': {'initial': {'editTweetIds': ['1563149113012928512'],
#         'editableUntilMsecs': '1661520565000',
#         'editsRemaining': '5',
#         'isEditEligible': False}}},
#      'ttl': -1},
#     'superFollowMetadata': {'r': {'ok': {}}, 'ttl': -1}}},
#   '1563149017256669185': {'created_at': datetime.datetime(2022, 8, 26, 12, 59, 2),
#    'id': 1563149017256669185,
#    'id_str': '1563149017256669185',
#    'full_text': 'Congratulations to the users who earned #BTC through Bitcoin Mondays with \n@CoinMENA\n\n🎉@Shab309\n🎉@K7RMA\n\nSet your schedules to participate in our fun #BTC Contest posted every Monday at 8 PM Bahrain time! https://t.co/xkpbG7QzWI',
#    'truncated': False,
#    'display_text_range': [0, 204],
#    'entities': {'hashtags': [{'text': 'BTC', 'indices': [40, 44]},
#      {'text': 'BTC', 'indices': [150, 154]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'CoinMENA',
#       'name': 'CoinMENA | كوين مينا',
#       'id': 1122914778492620801,
#       'id_str': '1122914778492620801',
#       'indices': [75, 84]},
#      {'screen_name': 'Shab309',
#       'name': 'Shab122',
#       'id': 1447794803979206658,
#       'id_str': '1447794803979206658',
#       'indices': [87, 95]},
#      {'screen_name': 'K7RMA',
#       'name': 'Eng , BTC💵',
#       'id': 303576677,
#       'id_str': '303576677',
#       'indices': [97, 103]}],
#     'urls': [],
#     'media': [{'id': 1563149013066698752,
#       'id_str': '1563149013066698752',
#       'indices': [205, 228],
#       'media_url': 'http://pbs.twimg.com/media/FbFrvtbX0AAPhmE.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/FbFrvtbX0AAPhmE.jpg',
#       'url': 'https://t.co/xkpbG7QzWI',
#       'display_url': 'pic.twitter.com/xkpbG7QzWI',
#       'expanded_url': 'https://twitter.com/CoinMENA/status/1563149017256669185/photo/1',
#       'type': 'photo',
#       'original_info': {'width': 2500,
#        'height': 2500,
#        'focus_rects': [{'x': 0, 'y': 0, 'h': 1400, 'w': 2500},
#         {'x': 0, 'y': 0, 'h': 2500, 'w': 2500},
#         {'x': 307, 'y': 0, 'h': 2500, 'w': 2193},
#         {'x': 812, 'y': 0, 'h': 2500, 'w': 1250},
#         {'x': 0, 'y': 0, 'h': 2500, 'w': 2500}]},
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#        'large': {'w': 2048, 'h': 2048, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1563149013066698752,
#       'id_str': '1563149013066698752',
#       'indices': [205, 228],
#       'media_url': 'http://pbs.twimg.com/media/FbFrvtbX0AAPhmE.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/FbFrvtbX0AAPhmE.jpg',
#       'url': 'https://t.co/xkpbG7QzWI',
#       'display_url': 'pic.twitter.com/xkpbG7QzWI',
#       'expanded_url': 'https://twitter.com/CoinMENA/status/1563149017256669185/photo/1',
#       'type': 'photo',
#       'original_info': {'width': 2500,
#        'height': 2500,
#        'focus_rects': [{'x': 0, 'y': 0, 'h': 1400, 'w': 2500},
#         {'x': 0, 'y': 0, 'h': 2500, 'w': 2500},
#         {'x': 307, 'y': 0, 'h': 2500, 'w': 2193},
#         {'x': 812, 'y': 0, 'h': 2500, 'w': 1250},
#         {'x': 0, 'y': 0, 'h': 2500, 'w': 2500}]},
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 1200, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#        'large': {'w': 2048, 'h': 2048, 'resize': 'fit'}},
#       'media_key': '3_1563149013066698752',
#       'ext_sensitive_media_warning': None,
#       'ext_media_availability': {'status': 'available'},
#       'ext_alt_text': None,
#       'ext_media_color': {'palette': [{'rgb': {'red': 222,
#           'green': 234,
#           'blue': 250},
#          'percentage': 91.16},
#         {'rgb': {'red': 254, 'green': 149, 'blue': 26}, 'percentage': 2.45},
#         {'rgb': {'red': 235, 'green': 195, 'blue': 164}, 'percentage': 1.92},
#         {'rgb': {'red': 61, 'green': 80, 'blue': 104}, 'percentage': 1.86},
#         {'rgb': {'red': 243, 'green': 179, 'blue': 105}, 'percentage': 0.89}]},
#       'ext': {'mediaStats': {'r': 'Missing', 'ttl': -1}}}]},
#    'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user_id': 1122914778492620801,
#    'user_id_str': '1122914778492620801',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 6,
#    'reply_count': 4,
#    'quote_count': 0,
#    'conversation_id': 1563149017256669185,
#    'conversation_id_str': '1563149017256669185',
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'possibly_sensitive_editable': True,
#    'lang': 'en',
#    'supplemental_language': None,
#    'ext_edit_control': {'initial': {'edit_tweet_ids': ['1563149017256669185'],
#      'editable_until_msecs': '1661520542000',
#      'edits_remaining': '5',
#      'is_edit_eligible': True}},
#    'ext': {'superFollowMetadata': {'r': {'ok': {}}, 'ttl': -1},
#     'editControl': {'r': {'ok': {'initial': {'editTweetIds': ['1563149017256669185'],
#         'editableUntilMsecs': '1661520542000',
#         'editsRemaining': '5',
#         'isEditEligible': True}}},
#      'ttl': -1},
#     'unmentionInfo': {'r': {'ok': {}}, 'ttl': -1}}},
#   '1563149041822998528': {'created_at': datetime.datetime(2022, 8, 26, 12, 59, 8),
#    'id': 1563149041822998528,
#    'id_str': '1563149041822998528',
#    'full_text': '@WhaleEverything $SYS. Bitcoin and Ethereum in one place',
#    'truncated': False,
#    'display_text_range': [17, 56],
#    'entities': {'hashtags': [],
#     'symbols': [{'text': 'SYS', 'indices': [17, 21]}],
#     'user_mentions': [{'screen_name': 'WhaleEverything',
#       'name': 'WHALE 🐳 EVERYTHING',
#       'id': 1476262356019814411,
#       'id_str': '1476262356019814411',
#       'indices': [0, 16]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1562777879746060288,
#    'in_reply_to_status_id_str': '1562777879746060288',
#    'in_reply_to_user_id': 1476262356019814411,
#    'in_reply_to_user_id_str': '1476262356019814411',
#    'in_reply_to_screen_name': 'WhaleEverything',
#    'user_id': 842164063987732480,
#    'user_id_str': '842164063987732480',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'reply_count': 0,
#    'quote_count': 0,
#    'conversation_id': 1562777879746060288,
#    'conversation_id_str': '1562777879746060288',
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en',
#    'supplemental_language': None,
#    'ext_edit_control': {'initial': {'edit_tweet_ids': ['1563149041822998528'],
#      'editable_until_msecs': '1661520548000',
#      'edits_remaining': '5',
#      'is_edit_eligible': False}},
#    'ext': {'editControl': {'r': {'ok': {'initial': {'editTweetIds': ['1563149041822998528'],
#         'editableUntilMsecs': '1661520548000',
#         'editsRemaining': '5',
#         'isEditEligible': False}}},
#      'ttl': -1},
#     'superFollowMetadata': {'r': {'ok': {}}, 'ttl': -1},
#     'unmentionInfo': {'r': {'ok': {}}, 'ttl': -1}}},
#   '1563149092469239808': {'created_at': datetime.datetime(2022, 8, 26, 12, 59, 20),
#    'id': 1563149092469239808,
#    'id_str': '1563149092469239808',
#    'full_text': 'Bounced off value area low will now look for a long value area high 21580\n\n$BTC #Bitcoin',
#    'truncated': False,
#    'display_text_range': [0, 88],
#    'entities': {'hashtags': [{'text': 'Bitcoin', 'indices': [80, 88]}],
#     'symbols': [{'text': 'BTC', 'indices': [75, 79]}],
#     'user_mentions': [],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user_id': 1556910555817984000,
#    'user_id_str': '1556910555817984000',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1563138826674900997,
#    'quoted_status_id_str': '1563138826674900997',
#    'quoted_status_permalink': {'url': 'https://t.co/2qspOyF2ve',
#     'expanded': 'https://twitter.com/CryptoKarma_/status/1563138826674900997',
#     'display': 'twitter.com/CryptoKarma_/s…'},
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'reply_count': 0,
#    'quote_count': 0,
#    'conversation_id': 1563149092469239808,
#    'conversation_id_str': '1563149092469239808',
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en',
#    'supplemental_language': None,
#    'ext_edit_control': {'initial': {'edit_tweet_ids': ['1563149092469239808'],
#      'editable_until_msecs': '1661520560000',
#      'edits_remaining': '5',
#      'is_edit_eligible': True}},
#    'ext': {'editControl': {'r': {'ok': {'initial': {'editTweetIds': ['1563149092469239808'],
#         'editableUntilMsecs': '1661520560000',
#         'editsRemaining': '5',
#         'isEditEligible': True}}},
#      'ttl': -1},
#     'superFollowMetadata': {'r': {'ok': {}}, 'ttl': -1},
#     'unmentionInfo': {'r': {'ok': {}}, 'ttl': -1}}},
#   '1563149067458187264': {'created_at': datetime.datetime(2022, 8, 26, 12, 59, 14),
#    'id': 1563149067458187264,
#    'id_str': '1563149067458187264',
#    'full_text': 'Shitcoins are a manner for founders to get extra bitcoin',
#    'truncated': False,
#    'display_text_range': [0, 56],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user_id': 1535074805686616064,
#    'user_id_str': '1535074805686616064',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'reply_count': 0,
#    'quote_count': 0,
#    'conversation_id': 1563149067458187264,
#    'conversation_id_str': '1563149067458187264',
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en',
#    'supplemental_language': None,
#    'ext_edit_control': {'initial': {'edit_tweet_ids': ['1563149067458187264'],
#      'editable_until_msecs': '1661520554000',
#      'edits_remaining': '5',
#      'is_edit_eligible': True}},
#    'ext': {'editControl': {'r': {'ok': {'initial': {'editTweetIds': ['1563149067458187264'],
#         'editableUntilMsecs': '1661520554000',
#         'editsRemaining': '5',
#         'isEditEligible': True}}},
#      'ttl': -1},
#     'superFollowMetadata': {'r': {'ok': {}}, 'ttl': -1},
#     'unmentionInfo': {'r': {'ok': {}}, 'ttl': -1}}},
#   '1563149216662585351': {'created_at': datetime.datetime(2022, 8, 26, 12, 59, 49),
#    'id': 1563149216662585351,
#    'id_str': '1563149216662585351',
#    'full_text': 'Many expect a new #crypto bull market to begin any day.\n\nBut are you mentally prepared for something like this?\n\n$TOTAL $BTC $ETH #Bitcoin https://t.co/eY3oCorpuX',
#    'truncated': False,
#    'display_text_range': [0, 138],
#    'entities': {'hashtags': [{'text': 'crypto', 'indices': [18, 25]},
#      {'text': 'Bitcoin', 'indices': [130, 138]}],
#     'symbols': [{'text': 'TOTAL', 'indices': [113, 119]},
#      {'text': 'BTC', 'indices': [120, 124]},
#      {'text': 'ETH', 'indices': [125, 129]}],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1563146967567532032,
#       'id_str': '1563146967567532032',
#       'indices': [139, 162],
#       'media_url': 'http://pbs.twimg.com/media/FbFp4pWXgAAo--I.png',
#       'media_url_https': 'https://pbs.twimg.com/media/FbFp4pWXgAAo--I.png',
#       'url': 'https://t.co/eY3oCorpuX',
#       'display_url': 'pic.twitter.com/eY3oCorpuX',
#       'expanded_url': 'https://twitter.com/JustinBennettFX/status/1563149216662585351/photo/1',
#       'type': 'photo',
#       'original_info': {'width': 1832,
#        'height': 1032,
#        'focus_rects': [{'x': 0, 'y': 0, 'h': 1026, 'w': 1832},
#         {'x': 800, 'y': 0, 'h': 1032, 'w': 1032},
#         {'x': 876, 'y': 0, 'h': 1032, 'w': 905},
#         {'x': 1070, 'y': 0, 'h': 1032, 'w': 516},
#         {'x': 0, 'y': 0, 'h': 1032, 'w': 1832}]},
#       'sizes': {'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#        'large': {'w': 1832, 'h': 1032, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 676, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}}}]},
#    'extended_entities': {'media': [{'id': 1563146967567532032,
#       'id_str': '1563146967567532032',
#       'indices': [139, 162],
#       'media_url': 'http://pbs.twimg.com/media/FbFp4pWXgAAo--I.png',
#       'media_url_https': 'https://pbs.twimg.com/media/FbFp4pWXgAAo--I.png',
#       'url': 'https://t.co/eY3oCorpuX',
#       'display_url': 'pic.twitter.com/eY3oCorpuX',
#       'expanded_url': 'https://twitter.com/JustinBennettFX/status/1563149216662585351/photo/1',
#       'type': 'photo',
#       'original_info': {'width': 1832,
#        'height': 1032,
#        'focus_rects': [{'x': 0, 'y': 0, 'h': 1026, 'w': 1832},
#         {'x': 800, 'y': 0, 'h': 1032, 'w': 1032},
#         {'x': 876, 'y': 0, 'h': 1032, 'w': 905},
#         {'x': 1070, 'y': 0, 'h': 1032, 'w': 516},
#         {'x': 0, 'y': 0, 'h': 1032, 'w': 1832}]},
#       'sizes': {'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#        'large': {'w': 1832, 'h': 1032, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 676, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}},
#       'media_key': '3_1563146967567532032',
#       'ext_sensitive_media_warning': None,
#       'ext_media_availability': {'status': 'available'},
#       'ext_alt_text': None,
#       'ext_media_color': {'palette': [{'rgb': {'red': 0,
#           'green': 0,
#           'blue': 0},
#          'percentage': 96.61},
#         {'rgb': {'red': 12, 'green': 28, 'blue': 73}, 'percentage': 2.22},
#         {'rgb': {'red': 51, 'green': 27, 'blue': 26}, 'percentage': 0.5},
#         {'rgb': {'red': 45, 'green': 98, 'blue': 49}, 'percentage': 0.25},
#         {'rgb': {'red': 50, 'green': 47, 'blue': 23}, 'percentage': 0.21}]},
#       'ext': {'mediaStats': {'r': 'Missing', 'ttl': -1}}}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user_id': 2420706757,
#    'user_id_str': '2420706757',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 47,
#    'favorite_count': 328,
#    'reply_count': 77,
#    'quote_count': 7,
#    'conversation_id': 1563149216662585351,
#    'conversation_id_str': '1563149216662585351',
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'possibly_sensitive_editable': True,
#    'lang': 'en',
#    'supplemental_language': None,
#    'self_thread': {'id': 1563149216662585351, 'id_str': '1563149216662585351'},
#    'ext_edit_control': {'initial': {'edit_tweet_ids': ['1563149216662585351'],
#      'editable_until_msecs': '1661520589000',
#      'edits_remaining': '5',
#      'is_edit_eligible': False}},
#    'ext': {'superFollowMetadata': {'r': {'ok': {}}, 'ttl': -1},
#     'editControl': {'r': {'ok': {'initial': {'editTweetIds': ['1563149216662585351'],
#         'editableUntilMsecs': '1661520589000',
#         'editsRemaining': '5',
#         'isEditEligible': False}}},
#      'ttl': -1},
#     'unmentionInfo': {'r': {'ok': {}}, 'ttl': -1}}},
#   '1563149110915772416': {'created_at': datetime.datetime(2022, 8, 26, 12, 59, 24),
#    'id': 1563149110915772416,
#    'id_str': '1563149110915772416',
#    'full_text': 'We might be seeing #Bitcoin above 22k soon',
#    'truncated': False,
#    'display_text_range': [0, 42],
#    'entities': {'hashtags': [{'text': 'Bitcoin', 'indices': [19, 27]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user_id': 1317006199406080000,
#    'user_id_str': '1317006199406080000',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'reply_count': 1,
#    'quote_count': 0,
#    'conversation_id': 1563149110915772416,
#    'conversation_id_str': '1563149110915772416',
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en',
#    'supplemental_language': None,
#    'ext_edit_control': {'initial': {'edit_tweet_ids': ['1563149110915772416'],
#      'editable_until_msecs': '1661520564000',
#      'edits_remaining': '5',
#      'is_edit_eligible': True}},
#    'ext': {'unmentionInfo': {'r': {'ok': {}}, 'ttl': -1},
#     'superFollowMetadata': {'r': {'ok': {}}, 'ttl': -1},
#     'editControl': {'r': {'ok': {'initial': {'editTweetIds': ['1563149110915772416'],
#         'editableUntilMsecs': '1661520564000',
#         'editsRemaining': '5',
#         'isEditEligible': True}}},
#      'ttl': -1}}},
#   '1563149166876172290': {'created_at': datetime.datetime(2022, 8, 26, 12, 59, 37),
#    'id': 1563149166876172290,
#    'id_str': '1563149166876172290',
#    'full_text': 'For you learn \nThen you remove the L to earn..\nThat’s how Good Bitcoin is to investors https://t.co/HpXqcFH9mJ',
#    'truncated': False,
#    'display_text_range': [0, 86],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1563149154485927936,
#       'id_str': '1563149154485927936',
#       'indices': [87, 110],
#       'media_url': 'http://pbs.twimg.com/media/FbFr38QWAAA6XW9.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/FbFr38QWAAA6XW9.jpg',
#       'url': 'https://t.co/HpXqcFH9mJ',
#       'display_url': 'pic.twitter.com/HpXqcFH9mJ',
#       'expanded_url': 'https://twitter.com/ninawrightffx/status/1563149166876172290/photo/1',
#       'type': 'photo',
#       'original_info': {'width': 1016,
#        'height': 866,
#        'focus_rects': [{'x': 0, 'y': 297, 'h': 569, 'w': 1016},
#         {'x': 0, 'y': 0, 'h': 866, 'w': 866},
#         {'x': 0, 'y': 0, 'h': 866, 'w': 760},
#         {'x': 12, 'y': 0, 'h': 866, 'w': 433},
#         {'x': 0, 'y': 0, 'h': 866, 'w': 1016}]},
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 680, 'h': 580, 'resize': 'fit'},
#        'large': {'w': 1016, 'h': 866, 'resize': 'fit'},
#        'medium': {'w': 1016, 'h': 866, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1563149154485927936,
#       'id_str': '1563149154485927936',
#       'indices': [87, 110],
#       'media_url': 'http://pbs.twimg.com/media/FbFr38QWAAA6XW9.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/FbFr38QWAAA6XW9.jpg',
#       'url': 'https://t.co/HpXqcFH9mJ',
#       'display_url': 'pic.twitter.com/HpXqcFH9mJ',
# ...
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 4294,
#    'media_count': 701,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1543668665622708226/YUQGxq-Z_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1543668665622708226/YUQGxq-Z_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1001769946903433216/1614588402',
#    'profile_image_extensions_sensitive_media_warning': None,
#    'profile_image_extensions_media_availability': None,
#    'profile_image_extensions_alt_text': None,
#    'profile_image_extensions_media_color': {'palette': [{'rgb': {'red': 6,
#        'green': 3,
#        'blue': 2},
#       'percentage': 83.73},
#      {'rgb': {'red': 57, 'green': 33, 'blue': 19}, 'percentage': 8.27},
#      {'rgb': {'red': 238, 'green': 186, 'blue': 166}, 'percentage': 4.04},
#      {'rgb': {'red': 42, 'green': 65, 'blue': 100}, 'percentage': 1.59},
#      {'rgb': {'red': 153, 'green': 94, 'blue': 73}, 'percentage': 0.94}]},
#    'profile_image_extensions': {'mediaStats': {'r': {'missing': None},
#      'ttl': -1}},
#    'profile_banner_extensions_sensitive_media_warning': None,
#    'profile_banner_extensions_media_availability': None,
#    'profile_banner_extensions_alt_text': None,
#    'profile_banner_extensions_media_color': {'palette': [{'rgb': {'red': 63,
#        'green': 42,
#        'blue': 30},
#       'percentage': 70.55},
#      {'rgb': {'red': 130, 'green': 97, 'blue': 70}, 'percentage': 13.61},
#      {'rgb': {'red': 18, 'green': 9, 'blue': 7}, 'percentage': 7.87},
#      {'rgb': {'red': 102, 'green': 67, 'blue': 28}, 'percentage': 4.02},
#      {'rgb': {'red': 227, 'green': 219, 'blue': 195}, 'percentage': 1.29}]},
#    'profile_banner_extensions': {'mediaStats': {'r': {'missing': None},
#      'ttl': -1}},
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'pinned_tweet_ids': [1554043534520586240],
#    'pinned_tweet_ids_str': ['1554043534520586240'],
#    'has_custom_timelines': True,
#    'can_dm': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'muting': None,
#    'blocking': None,
#    'blocked_by': None,
#    'want_retweets': None,
#    'advertiser_account_type': 'promotable_user',
#    'advertiser_account_service_levels': ['smb'],
#    'profile_interstitial_type': '',
#    'business_profile_state': 'none',
#    'translator_type': 'none',
#    'withheld_in_countries': [],
#    'followed_by': None,
#    'ext_has_nft_avatar': False,
#    'ext': {'hasNftAvatar': {'r': {'ok': False}, 'ttl': -1},
#     'superFollowMetadata': {'r': {'ok': {'superFollowEligible': False,
#        'superFollowing': False,
#        'superFollowedBy': False,
#        'exclusiveTweetFollowing': False,
#        'privateSuperFollowing': False}},
#      'ttl': -1},
#     'highlightedLabel': {'r': {'ok': {}}, 'ttl': -1}},
#    'require_some_consent': False},
#   '2379681079': {'id': 2379681079,
#    'id_str': '2379681079',
#    'name': 'Daniel Puton 🇧🇷⚡',
#    'screen_name': 'DanielPuton',
#    'location': 'Espírito Santo, Brasil',
#    'description': 'Um capixaba bitcoinheiro fã de anime, línguas, Age of Empires e vascaíno. O Espírito Santo é o meu país! #Bitcoin',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 122,
#    'fast_followers_count': 0,
#    'normal_followers_count': 122,
#    'friends_count': 672,
#    'listed_count': 1,
#    'created_at': 'Sun Mar 09 02:39:16 +0000 2014',
#    'favourites_count': 6818,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 1589,
#    'media_count': 136,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1362765937506734080/HcLeTy1F_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1362765937506734080/HcLeTy1F_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2379681079/1613306061',
#    'profile_image_extensions_sensitive_media_warning': None,
#    'profile_image_extensions_media_availability': None,
#    'profile_image_extensions_alt_text': None,
#    'profile_image_extensions_media_color': {'palette': [{'rgb': {'red': 247,
#        'green': 247,
#        'blue': 247},
#       'percentage': 51.87},
#      {'rgb': {'red': 21, 'green': 21, 'blue': 21}, 'percentage': 29.85},
#      {'rgb': {'red': 237, 'green': 161, 'blue': 140}, 'percentage': 8.45},
#      {'rgb': {'red': 87, 'green': 23, 'blue': 19}, 'percentage': 4.58},
#      {'rgb': {'red': 163, 'green': 28, 'blue': 20}, 'percentage': 2.47}]},
#    'profile_image_extensions': {'mediaStats': {'r': {'missing': None},
#      'ttl': -1}},
#    'profile_banner_extensions_sensitive_media_warning': None,
#    'profile_banner_extensions_media_availability': None,
#    'profile_banner_extensions_alt_text': None,
#    'profile_banner_extensions_media_color': {'palette': [{'rgb': {'red': 68,
#        'green': 34,
#        'blue': 22},
#       'percentage': 42.21},
#      {'rgb': {'red': 109, 'green': 71, 'blue': 33}, 'percentage': 29.23},
#      {'rgb': {'red': 202, 'green': 204, 'blue': 217}, 'percentage': 13.34},
#      {'rgb': {'red': 167, 'green': 144, 'blue': 94}, 'percentage': 6.18},
#      {'rgb': {'red': 95, 'green': 79, 'blue': 63}, 'percentage': 2.67}]},
#    'profile_banner_extensions': {'mediaStats': {'r': {'missing': None},
#      'ttl': -1}},
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'pinned_tweet_ids': [],
#    'pinned_tweet_ids_str': [],
#    'has_custom_timelines': True,
#    'can_dm': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'muting': None,
#    'blocking': None,
#    'blocked_by': None,
#    'want_retweets': None,
#    'advertiser_account_type': 'promotable_user',
#    'advertiser_account_service_levels': [],
#    'profile_interstitial_type': '',
#    'business_profile_state': 'none',
#    'translator_type': 'none',
#    'withheld_in_countries': [],
#    'followed_by': None,
#    'ext_has_nft_avatar': False,
#    'ext': {'superFollowMetadata': {'r': {'ok': {'superFollowEligible': False,
#        'superFollowing': False,
#        'superFollowedBy': False,
#        'exclusiveTweetFollowing': False,
#        'privateSuperFollowing': False}},
#      'ttl': -1},
#     'highlightedLabel': {'r': {'ok': {}}, 'ttl': -1},
#     'hasNftAvatar': {'r': {'ok': False}, 'ttl': -1}},
#    'require_some_consent': False},
#   '1519969669880315905': {'id': 1519969669880315905,
#    'id_str': '1519969669880315905',
#    'name': 'Crypto Alliance',
#    'screen_name': 'crypto_all1ance',
#    'location': 'crypto space',
#    'description': 'join the alliance\nGROUP: https://t.co/tA4pYrUnDv\nCHANNEL: https://t.co/68HxGO6Vf0',
#    'url': 'https://t.co/7Vvl54HVjq',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/7Vvl54HVjq',
#        'expanded_url': 'http://metfx.io',
#        'display_url': 'metfx.io',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/tA4pYrUnDv',
#        'expanded_url': 'http://t.me/Crypto_alliances',
#        'display_url': 't.me/Crypto_allianc…',
#        'indices': [25, 48]},
#       {'url': 'https://t.co/68HxGO6Vf0',
#        'expanded_url': 'http://t.me/CryptoAlliances',
#        'display_url': 't.me/CryptoAlliances',
#        'indices': [58, 81]}]}},
#    'protected': False,
#    'followers_count': 20,
#    'fast_followers_count': 0,
#    'normal_followers_count': 20,
#    'friends_count': 20,
#    'listed_count': 1,
#    'created_at': 'Fri Apr 29 09:20:03 +0000 2022',
#    'favourites_count': 69,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 2042,
#    'media_count': 1867,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1552188489873379330/gimPWAl9_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1552188489873379330/gimPWAl9_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1519969669880315905/1660558944',
#    'profile_image_extensions_sensitive_media_warning': None,
#    'profile_image_extensions_media_availability': None,
#    'profile_image_extensions_alt_text': None,
#    'profile_image_extensions_media_color': {'palette': [{'rgb': {'red': 27,
#        'green': 15,
#        'blue': 35},
#       'percentage': 71.09},
#      {'rgb': {'red': 132, 'green': 2, 'blue': 205}, 'percentage': 15.29},
#      {'rgb': {'red': 88, 'green': 11, 'blue': 140}, 'percentage': 6.02},
#      {'rgb': {'red': 167, 'green': 2, 'blue': 248}, 'percentage': 3.08},
#      {'rgb': {'red': 52, 'green': 11, 'blue': 84}, 'percentage': 2.33}]},
#    'profile_image_extensions': {'mediaStats': {'r': {'missing': None},
#      'ttl': -1}},
#    'profile_banner_extensions_sensitive_media_warning': None,
#    'profile_banner_extensions_media_availability': None,
#    'profile_banner_extensions_alt_text': None,
#    'profile_banner_extensions_media_color': {'palette': [{'rgb': {'red': 23,
#        'green': 10,
#        'blue': 63},
#       'percentage': 69.42},
#      {'rgb': {'red': 34, 'green': 30, 'blue': 44}, 'percentage': 9.08},
#      {'rgb': {'red': 76, 'green': 16, 'blue': 124}, 'percentage': 7.12},
#      {'rgb': {'red': 188, 'green': 181, 'blue': 190}, 'percentage': 4.22},
#      {'rgb': {'red': 252, 'green': 1, 'blue': 244}, 'percentage': 1.27}]},
#    'profile_banner_extensions': {'mediaStats': {'r': {'missing': None},
#      'ttl': -1}},
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'pinned_tweet_ids': [],
#    'pinned_tweet_ids_str': [],
#    'has_custom_timelines': False,
#    'can_dm': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'muting': None,
#    'blocking': None,
#    'blocked_by': None,
#    'want_retweets': None,
#    'advertiser_account_type': 'none',
#    'advertiser_account_service_levels': [],
#    'profile_interstitial_type': '',
#    'business_profile_state': 'none',
#    'translator_type': 'none',
#    'withheld_in_countries': [],
#    'followed_by': None,
#    'ext_has_nft_avatar': False,
#    'ext': {'superFollowMetadata': {'r': {'ok': {'superFollowEligible': False,
#        'superFollowing': False,
#        'superFollowedBy': False,
#        'exclusiveTweetFollowing': False,
#        'privateSuperFollowing': False}},
#      'ttl': -1},
#     'highlightedLabel': {'r': {'ok': {}}, 'ttl': -1},
#     'hasNftAvatar': {'r': {'ok': False}, 'ttl': -1}},
#    'require_some_consent': False},
#   '1306545798486855680': {'id': 1306545798486855680,
#    'id_str': '1306545798486855680',
#    'name': 'Pablo🇨🇭₿',
#    'screen_name': 'Pablomg_03',
#    'location': 'Sevilla, España',
#    'description': 'Future Swiss Citizen🇨🇭\nADE US 📈\nEsto es el mercado, amigo ₿\nEmprendedor digital & Trader \n🟨⬛\n#bitcoin',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 207,
#    'fast_followers_count': 0,
#    'normal_followers_count': 207,
#    'friends_count': 282,
#    'listed_count': 2,
#    'created_at': 'Thu Sep 17 10:49:36 +0000 2020',
#    'favourites_count': 27110,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 6486,
#    'media_count': 356,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1478396066391375885/LHDJn1jJ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1478396066391375885/LHDJn1jJ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1306545798486855680/1656257886',
#    'profile_image_extensions_sensitive_media_warning': None,
#    'profile_image_extensions_media_availability': None,
#    'profile_image_extensions_alt_text': None,
#    'profile_image_extensions_media_color': {'palette': [{'rgb': {'red': 88,
#        'green': 87,
#        'blue': 87},
#       'percentage': 71.35},
#      {'rgb': {'red': 225, 'green': 211, 'blue': 192}, 'percentage': 17.45},
#      {'rgb': {'red': 49, 'green': 47, 'blue': 48}, 'percentage': 3.75},
#      {'rgb': {'red': 163, 'green': 125, 'blue': 96}, 'percentage': 2.2},
#      {'rgb': {'red': 57, 'green': 65, 'blue': 80}, 'percentage': 1.32}]},
#    'profile_image_extensions': {'mediaStats': {'r': {'missing': None},
#      'ttl': -1}},
#    'profile_banner_extensions_sensitive_media_warning': None,
#    'profile_banner_extensions_media_availability': None,
#    'profile_banner_extensions_alt_text': None,
#    'profile_banner_extensions_media_color': {'palette': [{'rgb': {'red': 36,
#        'green': 36,
#        'blue': 44},
#       'percentage': 60.43},
#      {'rgb': {'red': 131, 'green': 106, 'blue': 107}, 'percentage': 15.62},
#      {'rgb': {'red': 193, 'green': 201, 'blue': 212}, 'percentage': 11.48},
#      {'rgb': {'red': 44, 'green': 49, 'blue': 76}, 'percentage': 2.45},
#      {'rgb': {'red': 109, 'green': 71, 'blue': 71}, 'percentage': 1.31}]},
#    'profile_banner_extensions': {'mediaStats': {'r': {'missing': None},
#      'ttl': -1}},
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'pinned_tweet_ids': [1441099003702091785],
#    'pinned_tweet_ids_str': ['1441099003702091785'],
#    'has_custom_timelines': True,
#    'can_dm': None,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'muting': None,
#    'blocking': None,
#    'blocked_by': None,
#    'want_retweets': None,
#    'advertiser_account_type': 'none',
#    'advertiser_account_service_levels': [],
#    'profile_interstitial_type': '',
#    'business_profile_state': 'none',
#    'translator_type': 'none',
#    'withheld_in_countries': [],
#    'followed_by': None,
#    'ext_has_nft_avatar': False,
#    'ext': {'superFollowMetadata': {'r': {'ok': {'superFollowEligible': False,
#        'superFollowing': False,
#        'superFollowedBy': False,
#        'exclusiveTweetFollowing': False,
#        'privateSuperFollowing': False}},
#      'ttl': -1},
#     'hasNftAvatar': {'r': {'ok': False}, 'ttl': -1},
#     'highlightedLabel': {'r': {'ok': {}}, 'ttl': -1}},
#    'require_some_consent': False}},
#  'moments': {},
#  'cards': {},
#  'places': {},
#  'media': {},
#  'broadcasts': {},
#  'topics': {},
#  'lists': {}}

# %%
tweets = data.get('tweets')
dates = [t['created_at'] for t in tweets.values()]
dates.sort()
dates
# Out:
# [datetime.datetime(2022, 8, 26, 12, 59),
#  datetime.datetime(2022, 8, 26, 12, 59),
#  datetime.datetime(2022, 8, 26, 12, 59, 2),
#  datetime.datetime(2022, 8, 26, 12, 59, 2),
#  datetime.datetime(2022, 8, 26, 12, 59, 2),
#  datetime.datetime(2022, 8, 26, 12, 59, 3),
#  datetime.datetime(2022, 8, 26, 12, 59, 4),
#  datetime.datetime(2022, 8, 26, 12, 59, 4),
#  datetime.datetime(2022, 8, 26, 12, 59, 7),
#  datetime.datetime(2022, 8, 26, 12, 59, 7),
#  datetime.datetime(2022, 8, 26, 12, 59, 8),
#  datetime.datetime(2022, 8, 26, 12, 59, 8),
#  datetime.datetime(2022, 8, 26, 12, 59, 8),
#  datetime.datetime(2022, 8, 26, 12, 59, 14),
#  datetime.datetime(2022, 8, 26, 12, 59, 14),
#  datetime.datetime(2022, 8, 26, 12, 59, 17),
#  datetime.datetime(2022, 8, 26, 12, 59, 20),
#  datetime.datetime(2022, 8, 26, 12, 59, 22),
#  datetime.datetime(2022, 8, 26, 12, 59, 23),
#  datetime.datetime(2022, 8, 26, 12, 59, 24),
#  datetime.datetime(2022, 8, 26, 12, 59, 24),
#  datetime.datetime(2022, 8, 26, 12, 59, 25),
#  datetime.datetime(2022, 8, 26, 12, 59, 25),
#  datetime.datetime(2022, 8, 26, 12, 59, 25),
#  datetime.datetime(2022, 8, 26, 12, 59, 26),
#  datetime.datetime(2022, 8, 26, 12, 59, 26),
#  datetime.datetime(2022, 8, 26, 12, 59, 27),
#  datetime.datetime(2022, 8, 26, 12, 59, 28),
#  datetime.datetime(2022, 8, 26, 12, 59, 29),
#  datetime.datetime(2022, 8, 26, 12, 59, 30),
#  datetime.datetime(2022, 8, 26, 12, 59, 31),
#  datetime.datetime(2022, 8, 26, 12, 59, 32),
#  datetime.datetime(2022, 8, 26, 12, 59, 32),
#  datetime.datetime(2022, 8, 26, 12, 59, 33),
#  datetime.datetime(2022, 8, 26, 12, 59, 34),
#  datetime.datetime(2022, 8, 26, 12, 59, 34),
#  datetime.datetime(2022, 8, 26, 12, 59, 34),
#  datetime.datetime(2022, 8, 26, 12, 59, 35),
#  datetime.datetime(2022, 8, 26, 12, 59, 36),
#  datetime.datetime(2022, 8, 26, 12, 59, 36),
#  datetime.datetime(2022, 8, 26, 12, 59, 37),
#  datetime.datetime(2022, 8, 26, 12, 59, 41),
#  datetime.datetime(2022, 8, 26, 12, 59, 42),
#  datetime.datetime(2022, 8, 26, 12, 59, 42),
#  datetime.datetime(2022, 8, 26, 12, 59, 43),
#  datetime.datetime(2022, 8, 26, 12, 59, 44),
#  datetime.datetime(2022, 8, 26, 12, 59, 46),
#  datetime.datetime(2022, 8, 26, 12, 59, 46),
#  datetime.datetime(2022, 8, 26, 12, 59, 48),
#  datetime.datetime(2022, 8, 26, 12, 59, 49),
#  datetime.datetime(2022, 8, 26, 12, 59, 49),
#  datetime.datetime(2022, 8, 26, 12, 59, 50),
#  datetime.datetime(2022, 8, 26, 12, 59, 52),
#  datetime.datetime(2022, 8, 26, 12, 59, 54),
#  datetime.datetime(2022, 8, 26, 12, 59, 55),
#  datetime.datetime(2022, 8, 26, 12, 59, 55),
#  datetime.datetime(2022, 8, 26, 12, 59, 58),
#  datetime.datetime(2022, 8, 26, 12, 59, 58)]

# %%
# scrape top tweets of with the hashtag #covid19, in proximity and without replies.
# the process is slower as the interval is smaller (choose an interval that can divide the period of time betwee, start and max date)
data = scrap(hashtag="covid19", start_date="2020-04-01", max_date="2020-04-15", from_account = None,interval=1,
      headless=True, display_type="Top", save_images=False, proxy = None, save_dir = 'outputs',
             resume=False, filter_replies=True, proximity=True)

# %%
data.head()

# %% [markdown]
# # Get the main information of a given list of users

# %%
# These users belongs to my following. 
users = ['nagouzil', '@yassineaitjeddi', 'TahaAlamIdrissi',] 
         #'@Nabila_Gl', 'geceeekusuu', '@pabu232', '@av_ahmet', '@x_born_to_die_x']

# %%
# this function return a list that contains : 
# ["nb of following","nb of followers", "join date", "birthdate", "location", "website", "description"]
users_info = get_user_information(users, headless=True)

# %%
import pandas as pd

users_df = pd.DataFrame(users_info, index = ["nb of following","nb of followers", "join date", 
                                             "birthdate", "location", "website", "description"]).T
users_df

# %% [markdown]
# # Get followers and following of a given list of users

# %% [markdown]
# Enter your username and password in .env file. I recommande you dont use your main account.
# Increase wait argument to avoid banning your account and maximise the crawling process if the internet is slow. I used 1 and it's safe.

# %%
users[0]

# %%
env_path = ".env"

# %%
following = get_users_following(users=['nagouzil'], env=env_path, verbose=0, headless = True, wait=2, file_path='outputs/')

# %%
following['nagouzil'][:10]

# %%
followers = get_users_followers(users=['nagouzil'], env=env_path, verbose=0, headless = True, wait=2, file_path='outputs/')

# %%
followers['nagouzil'][:10]
